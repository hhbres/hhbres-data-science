# %% [markdown]
# # PREDIÇÃO MORTALIDADE INFANTIL

# %%
import sys
import os
import pandas as pd
import numpy as np
import sys
sys.path
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
# %matplotlib inline

import plotly.offline as py
import plotly.graph_objs as go
import plotly.tools as tls
py.init_notebook_mode(connected=True)

import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Always good to set a seed for reproducibility
SEED = 7
np.random.seed(SEED)

# %% [markdown]
# ## 1 - Obter Dados - ANO 2016

# %%
# Loading Data SINASC AND SIM 2016
df_sinasc_es_2016_raw = pd.read_csv ('https://docs.google.com/spreadsheets/d/e/2PACX-1vSkaN1Ye-7puUZMT3J_yuJisowxrmsU3BAsvyfI3ZxD_mKPJ_4fjfnUS9_JH83fAocKWjyRquGMJxde/pub?output=csv')
df_sim_es_2016_raw = pd.read_csv ('https://docs.google.com/spreadsheets/d/e/2PACX-1vR_MH3HjwGWD0icAnZ3LVxxKUIxYNgAE3R-m-P61g0T2iXE9bs3hjeItGKTJqIUslIOAFN7TrE2ghGM/pub?output=csv')
# Getting dataframe columns names
df_sinasc_es_2016_name=df_sinasc_es_2016_raw.columns
df_sim_es_2016_name=df_sim_es_2016_raw.columns

# %% [markdown]
# ## 2 - Análise dos Dados

# %% [markdown]
# ### 2.1 - Estatística Descritiva

# %%
df_sinasc_es_2016_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53413 entries, 0 to 53412
# Data columns (total 65 columns):
# Unnamed: 0    53413 non-null int64
# NUMERODN      53413 non-null int64
# CODINST       53413 non-null object
# ORIGEM        53413 non-null int64
# NUMERODV      53413 non-null int64
# PREFIXODN     53413 non-null int64
# CODESTAB      53256 non-null float64
# CODMUNNASC    53413 non-null int64
# LOCNASC       53413 non-null int64
# IDADEMAE      53413 non-null int64
# ESTCIVMAE     53161 non-null float64
# ESCMAE        53372 non-null float64
# CODOCUPMAE    0 non-null float64
# QTDFILVIVO    53279 non-null float64
# QTDFILMORT    53189 non-null float64
# CODMUNRES     53413 non-null int64
# GESTACAO      53298 non-null float64
# GRAVIDEZ      53381 non-null float64
# PARTO         53393 non-null float64
# CONSULTAS     53413 non-null int64
# DTNASC        53413 non-null int64
# HORANASC      53371 non-null float64
# SEXO          53413 non-null int64
# ...

# %% [raw]
# -Existem features do tipo object, int e float
# -Não há valores nulos

# %%
df_sinasc_es_2016_raw.head()
# Out:
#    Unnamed: 0  NUMERODN        CODINST  ORIGEM  NUMERODV  PREFIXODN  \
# 0           1  69142346  MBA2910720001       1         8         30
# 1           2  69204731  MBA2913600002       1         1         30
# 2           3  69091312  MBA2922000001       1         7         30
# 3           4  69161083  MBA2922000001       1         7         30
# 4           5  69161493  MBA2922000001       1         0         30
#
#     CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE     ...      TPFUNCRESP  \
# 0  2507447.0      291072        1        16     ...             2.0
# 1  2802112.0      291360        1        18     ...             2.0
# 2  2506122.0      292200        1        21     ...             2.0
# 3  2506122.0      292200        1        20     ...             2.0
# 4  2498804.0      292200        1        17     ...             2.0
#
#    TPDOCRESP  DTDECLARAC  ESCMAEAGR1  STDNEPIDEM  STDNNOVA  CODPAISRES  \
# 0        3.0  26022016.0         3.0           0         1           1
# ...

# %%
df_sinasc_es_2016_raw.describe()
# Out:
#          Unnamed: 0      NUMERODN   ORIGEM      NUMERODV  PREFIXODN  \
# count  53413.000000  5.341300e+04  53413.0  53413.000000    53413.0
# mean   26707.000000  7.017404e+07      1.0      4.089585       30.0
# std    15419.149301  1.613396e+06      0.0      3.030791        0.0
# min        1.000000  5.498281e+07      1.0      0.000000       30.0
# 25%    13354.000000  6.882397e+07      1.0      1.000000       30.0
# 50%    26707.000000  7.108250e+07      1.0      4.000000       30.0
# 75%    40060.000000  7.109900e+07      1.0      7.000000       30.0
# max    53413.000000  7.509214e+07      1.0      9.000000       30.0
#
#            CODESTAB     CODMUNNASC       LOCNASC      IDADEMAE     ESTCIVMAE  \
# count  5.325600e+04   53413.000000  53413.000000  53413.000000  53161.000000
# mean   3.362035e+06  320300.966488      1.012151     26.757119      2.212073
# std    2.153294e+06    1971.363430      0.149334      6.644023      1.491102
# ...

# %%
df_sim_es_2016_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22868 entries, 0 to 22867
# Data columns (total 93 columns):
# Unnamed: 0    22868 non-null int64
# NUMERODO      22868 non-null int64
# CODINST       22868 non-null object
# NUMERODV      22868 non-null int64
# ORIGEM        22868 non-null int64
# TIPOBITO      22868 non-null int64
# DTOBITO       22868 non-null int64
# HORAOBITO     20713 non-null float64
# NUMSUS        1088 non-null float64
# NATURAL       19163 non-null float64
# CODMUNNATU    18743 non-null float64
# DTNASC        22824 non-null float64
# IDADE         22868 non-null int64
# SEXO          22868 non-null int64
# RACACOR       20026 non-null float64
# ESTCIV        21062 non-null float64
# ESC           19148 non-null float64
# ESC2010       19140 non-null float64
# SERIESCFAL    2933 non-null float64
# OCUP          17920 non-null float64
# CODMUNRES     22868 non-null int64
# LOCOCOR       22868 non-null int64
# CODESTAB      17191 non-null float64
# ...

# %% [raw]
# -Existem features do tipo object, int e float
# -Não há valores nulos

# %%
df_sim_es_2016_raw.head()
# Out:
#    Unnamed: 0  NUMERODO        CODINST  NUMERODV  ORIGEM  TIPOBITO  DTOBITO  \
# 0           1  22196183  MES3205000001         6       1         2  1012016
# 1           2  22196181  MES3205000001         0       1         2  1012016
# 2           3  22196182  MES3205000001         8       1         2  1012016
# 3           4  22201559  MES3205000001         4       1         2  1012016
# 4           5  22196184  MES3205000001         4       1         2  1012016
#
#    HORAOBITO        NUMSUS  NATURAL    ...     DTCONINV  FONTES  TPRESGINFO  \
# 0     1450.0  7.068018e+14    832.0    ...          NaN  SXSSXX         NaN
# 1      845.0           NaN    831.0    ...          NaN     NaN         NaN
# 2     1006.0           NaN    831.0    ...          NaN     NaN         NaN
# 3        NaN           NaN    832.0    ...          NaN     NaN         NaN
# 4     1200.0  7.028057e+14    832.0    ...          NaN     NaN         NaN
#
# ...

# %%
df_sim_es_2016_raw.describe()
# Out:
#          Unnamed: 0      NUMERODO      NUMERODV   ORIGEM  TIPOBITO  \
# count  22868.000000  2.286800e+04  22868.000000  22868.0   22868.0
# mean   11434.500000  2.304919e+07      4.105344      1.0       2.0
# std     6601.567314  9.360149e+05      3.031238      0.0       0.0
# min        1.000000  1.528605e+07      0.000000      1.0       2.0
# 25%     5717.750000  2.220426e+07      1.000000      1.0       2.0
# 50%    11434.500000  2.316692e+07      4.000000      1.0       2.0
# 75%    17151.250000  2.373608e+07      7.000000      1.0       2.0
# max    22868.000000  2.493748e+07      9.000000      1.0       2.0
#
#             DTOBITO    HORAOBITO        NUMSUS       NATURAL     CODMUNNATU  \
# count  2.286800e+04  20713.00000  1.088000e+03  19163.000000   18743.000000
# mean   1.576874e+07   1191.05890  6.636752e+14    829.306372  317641.379342
# std    8.833792e+06    673.87026  2.354536e+14     36.462966   17495.414499
# ...
